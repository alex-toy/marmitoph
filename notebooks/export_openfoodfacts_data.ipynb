# %%
import openfoodfacts
import pandas as pd

folder_path = "data"


category_1_list = []
category_2_list = []
product_list=[]
image_list=[]
barcode_list=[]

i = 0
for product in openfoodfacts.products.get_all_by_country("France"):
    if ('product_name' in product.keys()) & \
    ('image_small_url' in product.keys()) & \
    ('compared_to_category' in product.keys()) & \
    ('categories_old' in product.keys()) & \
    ('code' in product.keys()):

        i+=1
        image_list.append(product['image_small_url'])
        product_list.append(product['product_name'])
        category_1_list.append(product['categories_old'])
        category_2_list.append(product['compared_to_category'])
        barcode_list.append(product['code'])
        if i%1000 == 0:
            print("{} products".format(i))

        if i%5000 == 0:
            results = pd.DataFrame({'image_url' : image_list,
                        'barcode' : barcode_list,
                        'product_name': product_list,
                        'product_category_1': category_1_list,
                        'product_category_2': category_2_list,
                        })

            filename = "products_{}_{}.csv".format(i-5000, i)
            filepath = os.path.join(folder_path, filename)
            results.to_csv(filepath, index = False)

            category_1_list = []
            category_2_list = []
            product_list=[]
            image_list=[]
            barcode_list=[]
# Out:
# 1000 products
# 2000 products
# 3000 products
# 4000 products
# 5000 products
# 6000 products
# 7000 products
# 8000 products
# 9000 products
# 10000 products
# 11000 products
# 12000 products
# 13000 products
# 14000 products
# 15000 products
# 16000 products
# 17000 products
# 18000 products
# 19000 products
# 20000 products
# 21000 products
# 22000 products
# 23000 products
# 24000 products
# 25000 products
# 26000 products
# 27000 products
# 28000 products
# 29000 products
# 30000 products
# 31000 products
# 32000 products
# 33000 products
# 34000 products
# 35000 products
# 36000 products
# 37000 products
# 38000 products
# 39000 products
# 40000 products
# 41000 products
# 42000 products
# 43000 products
# 44000 products
# 45000 products
# 46000 products
# 47000 products
# 48000 products
# 49000 products
# 50000 products
# 51000 products
# 52000 products
# 53000 products
# 54000 products
# 55000 products
# 56000 products
# 57000 products
# 58000 products
# 59000 products
# ...
